# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoiaTahir-ai/OOPs-Project/blob/main/BankOOps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bank Account(OOPs)

# %%
class Bank:
    def __init__(self, name, account_number):
        self.name = name
        self.account_number = account_number
        self.balance = 0

    def deposit(self, amount):
        self.balance += amount
        print(f"${amount} deposited successfully.")
        print(f"Current balance: ${self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"${amount} withdrawn successfully.")
            print(f"Current balance: ${self.balance}")
        else:
            print("Insufficient balance.")

    def check_balance(self):
        print(f"Current balance: ${self.balance}")


# Create an account
name = input("Enter your name: ")
account_number = input("Enter your account number: ")

account = Bank(name, account_number)

while True:
    ch = input("\nDo you want to continue? (yes/no): ")

    if ch.lower() == "no":
        print("Thank you for using our bank system.")
        break

    user_name = input("Enter your name: ")
    user_account = input("Enter your account number: ")

    if user_name != account.name or user_account != account.account_number:
        print("Invalid account details.")
        continue

    print("\n1. Deposit")
    print("2. Withdraw")
    print("3. Check balance")
    print("4. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        amount = float(input("Enter the deposit amount: "))
        account.deposit(amount)

    elif choice == 2:
        amount = float(input("Enter the withdrawal amount: "))
        account.withdraw(amount)

    elif choice == 3:
        account.check_balance()

    elif choice == 4:
        print("Thank you for using our bank system.")
        break

    else:
        print("Invalid choice.")
# Out:
# Enter your name: Ali
# Enter your account number: 223366
#
# Do you want to continue? (yes/no): yes
# Enter your name: Ali
# Enter your account number: 223366
#
# 1. Deposit
# 2. Withdraw
# 3. Check balance
# 4. Exit
# Enter your choice: 1
# Enter the deposit amount: 400
# $400.0 deposited successfully.
# Current balance: $400.0
#
# Do you want to continue? (yes/no): no
# Thank you for using our bank system.
