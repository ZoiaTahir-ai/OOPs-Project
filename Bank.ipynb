# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoiaTahir-ai/OOPs-Project/blob/main/Bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bank Account Managment System**

# %%
print("--- Bank Management System ---")

balance = 0
name = ""
account_number = ""

while True:
    print("\n1. Create Account")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Check Balance")
    print("5. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        name = input("Enter your name: ")
        account_number = input("Enter your account number: ")

        print("\nAccount created successfully!")
        print(f"Account Holder: {name}")
        print(f"Account Number: {account_number}")
        print(f"Balance: ${balance}")

    elif choice == 2:
        nam = input("Enter your name: ")
        account = input("Enter your account number: ")

        if nam == name and account == account_number:
            deposit_amount = float(input("Enter the deposit amount: "))
            balance += deposit_amount

            print(f"${deposit_amount} deposited successfully.")
            print(f"Current balance: ${balance}")

        else:
            print("Invalid account details.")

    elif choice == 3:
        nam = input("Enter your name: ")
        account = input("Enter your account number: ")

        if nam == name and account == account_number:
            withdraw_amount = float(
                input("Enter the withdrawal amount: ")
            )

            if withdraw_amount <= balance:
                balance -= withdraw_amount

                print(f"${withdraw_amount} withdrawn successfully.")
                print(f"Current balance: ${balance}")

            else:
                print("Insufficient balance.")

        else:
            print("Invalid account details.")

    elif choice == 4:
        nam = input("Enter your name: ")
        account = input("Enter your account number: ")

        if nam == name and account == account_number:
            print(f"Current balance: ${balance}")

        else:
            print("Invalid account details.")

    elif choice == 5:
        print("Thank you for using our bank system.")
        break

    else:
        print("Invalid choice.")
# Out:
# --- Bank Management System ---
#
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Enter your choice: 1
# Enter your name: Ali
# Enter your account number: 2336608
#
# Account created successfully!
# Account Holder: Ali
# Account Number: 2336608
# Balance: $0
#
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Enter your choice: 2
# Enter your name: Ali
# Enter your account number: 2336608
# Enter the deposit amount: 4555
# $4555.0 deposited successfully.
# Current balance: $4555.0
#
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Enter your choice: 4
# Enter your name: Ali
# Enter your account number: 2336608
# Current balance: $4555.0
#
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Exit
# Enter your choice: 5
# Thank you for using our bank system.
